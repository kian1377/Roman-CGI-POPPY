# %% [markdown]
# # Import the various packages and the file containing the modes.
# pathlib is used to define paths conveniently such that both Windows and Linux/Mac users can set their directories.

# %%
import poppy
import numpy as np
import astropy.units as u
import astropy.io.fits as fits
from pathlib import Path

import poppy_romancgi_modes as modes
import polmap
import misc

from importlib import reload
reload(modes)
reload(polmap)
reload(misc)

from IPython.display import clear_output

# set debugging mode for more information from POPPY as propagation is performed
import logging, sys
_log = logging.getLogger('poppy')
_log.setLevel("DEBUG")
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %% [markdown]
# ## Check what packages are available for faster computations and use POPPY's configuration feature to set the options.
#
# The numexpr package only speeds up some calculations, but not the FFTs. POPPY defaults to numexpr if available, unless the user sets the conf value to False.
#
# MKL tends to be faster than pyFFTW so POPPY defaults to that if available, unless its conf value is set to False, in which case pyFFTW is used. If pyFFTW is not available or its conf value is set to False, poppy uses standard numpy FFTs.
#
# OPENCL uses a GPU so it tends to be faster than MKL and POPPY defaults to that if available, onca again unless the user sets the conf value to False.
#
# No testing was done with CUDA because a necessary package called pyculib must be installed, which has since been depreciated.

# %%
import poppy.accel_math as am
print(am._USE_NUMEXPR)
print(am._USE_FFTW)
print(am._USE_MKL)
print(am._USE_OPENCL)
print(am._USE_CUDA)
poppy.conf.use_numexpr = True
poppy.conf.use_fftw = False
poppy.conf.use_mkl = True
poppy.conf.use_opencl = False
poppy.conf.use_cuda = False
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# # Set the parameters of the mode being run and calculate a PSF.
# Both the PSF and the POPPY FresnelWavefront objects of each plane are returned by default. Note, these wavefront objects can take up quite a bit of memory.

# %%
reload(modes)

mode = 'SPC825'
use_dms = False
use_opds = False
use_apertures = False
use_fieldstop = False
polaxis = 0
cgi_dir = Path('C:/Users/Kian Milani/Desktop/roman-cgi-poppy-data')
# cgi_dir = Path('/groups/douglase/webbpsf-data/CGI')
psf, wfs = modes.run_model(mode=mode,
                           oversample=2,
#                            lambda_m=600e-9*u.m, 
#                            offsets=(4.5,0),
                           use_fpm=True,
                           use_opds=use_opds,
                           use_dms=use_dms, 
                           use_fieldstop=use_fieldstop,
                           use_apertures=use_apertures,
                           polaxis=polaxis,
                           cgi_dir=cgi_dir,
                           display_mode=False,
                           display_inwave=True,
                           display_intermediates=False,
                           display_fpm=True,
                           display_psf=True)
# Out:
# INFO:poppy:Initialized OpticalSystem: SPC825
# INFO:poppy:Added optic: Roman Pupil after separation: 0.00e+00 m
# INFO:poppy:Added optic: Primary after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary after separation: 2.29e+00 m
# INFO:poppy:Added optic: Fold 1 after separation: 2.99e+00 m
# INFO:poppy:Added optic: M3 after separation: 1.68e+00 m
# INFO:poppy:Added optic: M4 after separation: 9.44e-01 m
# INFO:poppy:Added optic: M5 after separation: 4.29e-01 m
# INFO:poppy:Added optic: Fold 2 after separation: 3.51e-01 m
# INFO:poppy:Added optic: FSM after separation: 3.65e-01 m
# INFO:poppy:Added optic: OAP1 after separation: 3.55e-01 m
# INFO:poppy:Added optic: FOCM after separation: 7.68e-01 m
# INFO:poppy:Added optic: OAP2 after separation: 3.14e-01 m
# INFO:poppy:Added optic: DM1 Plane (No Optic) after separation: 7.76e-01 m
# INFO:poppy:Added optic: DM2 Plane (No Optic) after separation: 1.00e+00 m
# INFO:poppy:Added optic: OAP3 after separation: 3.95e-01 m
# INFO:poppy:Added optic: Fold 3 after separation: 5.05e-01 m
# INFO:poppy:Added optic: OAP4 after separation: 1.16e+00 m
# INFO:poppy:Added optic: Shaped Pupil Mask after separation: 4.23e-01 m
# INFO:poppy:Added optic: OAP5 after separation: 4.09e-01 m
# INFO:poppy:Added optic: ANNULAR FPM after separation: 5.48e-01 m
# INFO:poppy:Added optic: OAP6 after separation: 5.48e-01 m
# INFO:poppy:Added optic: Lyot Stop after separation: 6.88e-01 m
# INFO:poppy:Added optic: OAP7 after separation: 4.02e-01 m
# INFO:poppy:Added optic: Fieldstop Plane (No Optic) after separation: 7.08e-01 m
# INFO:poppy:Added optic: OAP8 after separation: 2.11e-01 m
# INFO:poppy:Added optic: Filter after separation: 3.68e-01 m
# INFO:poppy:Added optic: LENS after separation: 1.71e-01 m
# INFO:poppy:Added optic: Fold 4 after separation: 2.46e-01 m
# INFO:poppy:Added optic: focus after separation: 5.00e-02 m
# DEBUG:poppy:Padded WF array for oversampling by 2, to (2000, 2000).
# Not employing polarization aberrations.
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy:User requested saving intermediate wavefronts in call to poppy.calc_psf
# INFO:poppy: Propagating wavelength = 8.25e-07 m
# INFO:poppy:Using user-defined FresnelWavefront() for the input wavefront of the FresnelOpticalSystem().
# DEBUG:poppy:Input wavefront has wavelength=0.8250000000000001 microns, npix=1000, diam=2.3633372 m, pixel scale=0.0023633372 m / pix
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Roman Pupil  after distance 0.0 m
# DEBUG:poppy:Array shape (1002, 1002) is smaller than desired shape [2000, 2000]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 499 x 499 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Roman Pupil
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Lens: Primary, with focal length 2.83827920690472 m after distance 0.0 m
# DEBUG:poppy:------ Applying Lens: Primary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.182e+00 m, z_w0=0.000e+00 m
# z=0.000e+00 m, z_r=5.317e+06 m
# DEBUG:poppy:  Beam radius at Primary =1.18e+00 m
# DEBUG:poppy: input flat wavefront and Primary has output beam curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curved output wavefront, with waist at 2.8382792069039113 m
# DEBUG:poppy:Post Optic Parameters:w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=0.000e+00 m, z_r=1.515e-06 m
# DEBUG:poppy:Set output beam focal length to 2.83827920690472 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =9.96e+12 m
# DEBUG:poppy:Applying spherical lens phase =1.00e-13 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Primary
# DEBUG:poppy:------ Optic: Primary applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: Secondary, with focal length -0.6542007965680045 m after distance 2.285150515460035 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 2.8382792069039113 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0023633372 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=2.8382792069039113 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.021826 s, full function  in 0.028 s
# DEBUG:poppy:Applying spherical phase curvature =2.84e+00 m
# DEBUG:poppy:Applying spherical lens phase =3.52e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 4.95397005915137e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5531286914438764 m
# DEBUG:poppy:Applying spherical phase curvature =-5.53e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.81e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.022320 s, full function  in 0.033 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 2.29e+00 m ------
# DEBUG:poppy:------ Applying Lens: Secondary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.515e-06 m
# DEBUG:poppy:  Beam radius at Secondary =2.30e-01 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.515e-06 m
# DEBUG:poppy: input curved wavefront and Secondary has output beam curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curved output wavefront, with waist at 5.865339431151831 m
# DEBUG:poppy:Post Optic Parameters:w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=2.285e+00 m, z_r=6.347e-05 m
# DEBUG:poppy:Magnification: 6.4726147317930955  from R_in = -0.5531286914438764 m, R_out = -3.580188916817072 m
# DEBUG:poppy:Output beam focal length is now 18.371087807553515 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-1.5286e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-1.8079e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-2.7931e-01 1 / m
# DEBUG:poppy:Applying spherical phase curvature =1.35e+10 m
# DEBUG:poppy:Applying spherical lens phase =7.42e-11 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Secondary
# DEBUG:poppy:------ Optic: Secondary applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 1 after distance 2.993753476654728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339431151831 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0004605711833060301 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=3.5801889156917963 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020832 s, full function  in 0.029 s
# DEBUG:poppy:Applying spherical phase curvature =3.58e+00 m
# DEBUG:poppy:Applying spherical lens phase =2.79e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 3.20651395756468e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5864354390370679 m
# DEBUG:poppy:Applying spherical phase curvature =-5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016868 s, full function  in 0.028 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 5.28e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 1
# DEBUG:poppy:  Propagating wavefront to Lens: M3, with focal length 0.430216463069001 m after distance 1.680935841598811 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339431151831 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 7.544162345905241e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5864354390370679 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019843 s, full function  in 0.026 s
# DEBUG:poppy:Applying spherical phase curvature =5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 3.2065139575646794e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=1.094500402561743 m
# DEBUG:poppy:Applying spherical phase curvature =1.09e+00 m
# DEBUG:poppy:Applying spherical lens phase =9.14e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018849 s, full function  in 0.025 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 6.96e+00 m ------
# DEBUG:poppy:------ Applying Lens: M3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=6.347e-05 m
# DEBUG:poppy:  Beam radius at M3 =7.04e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=6.347e-05 m
# DEBUG:poppy: input curved wavefront and M3 has output beam curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curved output wavefront, with waist at 7.668681433417899 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=6.960e+00 m, z_r=2.662e-05 m
# DEBUG:poppy:Magnification: -0.6476394152483825  from R_in = 1.094500402561743 m, R_out = -0.7088416007042065 m
# DEBUG:poppy:Output beam focal length is now -11.897840565160648 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=2.3244e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=9.1366e-01 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-1.4108e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =1.98e+08 m
# DEBUG:poppy:Applying spherical lens phase =5.06e-09 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M3
# DEBUG:poppy:------ Optic: M3 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M4, with focal length 0.11623911483359 m after distance 0.943514749358944 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 7.668681433417899 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.00014080132568629623 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7088415997043249 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.023312 s, full function  in 0.035 s
# DEBUG:poppy:Applying spherical phase curvature =7.09e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.076664821533653e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.23467314965461927 m
# DEBUG:poppy:Applying spherical phase curvature =2.35e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.26e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020338 s, full function  in 0.031 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 7.90e+00 m ------
# DEBUG:poppy:------ Applying Lens: M4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=2.662e-05 m
# DEBUG:poppy:  Beam radius at M4 =2.33e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=2.662e-05 m
# DEBUG:poppy: input curved wavefront and M4 has output beam curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curved output wavefront, with waist at 8.133678565106518 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=7.903e+00 m, z_r=2.564e-05 m
# DEBUG:poppy:Magnification: -0.9814671394164407  from R_in = 0.23467314965461927 m, R_out = -0.23032398488936548 m
# DEBUG:poppy:Output beam focal length is now 11.677339544721109 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=8.6030e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=4.2612e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-4.3417e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =9.20e+06 m
# DEBUG:poppy:Applying spherical lens phase =1.09e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M4
# DEBUG:poppy:------ Optic: M4 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M5, with focal length 0.198821518772608 m after distance 0.429145636743193 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 8.133678565106518 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.66144912885075e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.23032398203399929 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.022817 s, full function  in 0.035 s
# DEBUG:poppy:Applying spherical phase curvature =2.30e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.34e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.03817825664974e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.1988216547091941 m
# DEBUG:poppy:Applying spherical phase curvature =1.99e-01 m
# DEBUG:poppy:Applying spherical lens phase =5.03e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.029 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.33e+00 m ------
# DEBUG:poppy:------ Applying Lens: M5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=2.564e-05 m
# DEBUG:poppy:  Beam radius at M5 =2.01e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=2.564e-05 m
# DEBUG:poppy: input curved wavefront and M5 has output beam curvature of =-2.84e+05 m
# DEBUG:poppy:M5 has a curvature of =-2.84e+05 m
# DEBUG:poppy:M5 has a curved output wavefront, with waist at 16.701846535892614 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.012e-02 m, z_w0=1.670e+01 m
# z=8.333e+00 m, z_r=1.541e+03 m
# DEBUG:poppy:Magnification: -1427860.389179302  from R_in = 0.1988216547091941 m, R_out = -283889.5652703427 m
# DEBUG:poppy:Output beam focal length is now -16673610.586904336 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-2.91e+05 m
# DEBUG:poppy:Applying spherical lens phase =-3.44e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M5
# DEBUG:poppy:------ Optic: M5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 2 after distance 0.35112543122077 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 16.701846535892614 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.35112543122077 m
# DEBUG:poppy:  Constant Pixelscale: 4.023884186771433e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.021851 s, full function  in 0.034 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.021823 s, full function  in 0.028 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.68e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 2
# DEBUG:poppy:  Propagating wavefront to Optic: FSM after distance 0.365403811661862 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 16.701846535892614 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.365403811661862 m
# DEBUG:poppy:  Constant Pixelscale: 4.023884186771433e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.021331 s, full function  in 0.033 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.031 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.05e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FSM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP1, with focal length 0.503331895563883 m after distance 0.354826767220001 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 16.701846535892614 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.354826767220001 m
# DEBUG:poppy:  Constant Pixelscale: 4.023884186771433e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016866 s, full function  in 0.027 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020833 s, full function  in 0.027 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.40e+00 m ------
# DEBUG:poppy:------ Applying Lens: OAP1 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.012e-02 m, z_w0=1.670e+01 m
# z=9.404e+00 m, z_r=1.541e+03 m
# DEBUG:poppy:  Beam radius at OAP1 =2.01e-02 m
# DEBUG:poppy: input flat wavefront and OAP1 has output beam curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curved output wavefront, with waist at 9.907188071814195 m
# DEBUG:poppy:Post Optic Parameters:w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=9.404e+00 m, z_r=1.644e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.503331895563883 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =4.72e+06 m
# DEBUG:poppy:Applying spherical lens phase =2.12e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP1
# DEBUG:poppy:------ Optic: OAP1 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: FOCM after distance 0.768005607094041 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.907188071814195 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.023884186771433e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5033318418958501 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.022817 s, full function  in 0.031 s
# DEBUG:poppy:Applying spherical phase curvature =5.03e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.99e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 5.159800211561899e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.2646737651981912 m
# DEBUG:poppy:Applying spherical phase curvature =2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.021327 s, full function  in 0.027 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.02e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FOCM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP2, with focal length 0.579156922073536 m after distance 0.314483210543378 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.907188071814195 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 2.1159332467875752e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=-0.2646737651981912 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.032 s
# DEBUG:poppy:Applying spherical phase curvature =-2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =-3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 5.1598002115619e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.5791569757415687 m
# DEBUG:poppy:Applying spherical phase curvature =5.79e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.73e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019046 s, full function  in 0.030 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.05e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP2 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=1.049e+01 m, z_r=1.644e-04 m
# DEBUG:poppy:  Beam radius at OAP2 =2.32e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=1.049e+01 m, z_r=1.644e-04 m
# DEBUG:poppy: input curved wavefront and OAP2 has output beam curvature of =-3.34e+06 m
# DEBUG:poppy:OAP2 has a curvature of =-3.34e+06 m
# DEBUG:poppy:OAP2 has a curved output wavefront, with waist at 11.731906672008412 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.315e-02 m, z_w0=1.173e+01 m
# z=1.049e+01 m, z_r=2.041e+03 m
# DEBUG:poppy:Magnification: -5773690.297714872  from R_in = 0.5791569757415687 m, R_out = -3343873.0116929826 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-6.25e+06 m
# DEBUG:poppy:Applying spherical lens phase =-1.60e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP2
# DEBUG:poppy:------ Optic: OAP2 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: DM1 Plane (No Optic) after distance 0.775775726154228 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.731906672008412 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.775775726154228 m
# DEBUG:poppy:  Constant Pixelscale: 4.630067884374152e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019343 s, full function  in 0.025 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019842 s, full function  in 0.025 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.13e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM1 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Optic: DM2 Plane (No Optic) after distance 1.0 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.731906672008412 m
# DEBUG:poppy:  Plane to Plane Regime, dz=1.0 m
# DEBUG:poppy:  Constant Pixelscale: 4.630067884374152e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.028 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020337 s, full function  in 0.029 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.23e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM2 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP3, with focal length 1.217276467668519 m after distance 0.394833855161549 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.731906672008412 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.394833855161549 m
# DEBUG:poppy:  Constant Pixelscale: 4.630067884374152e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020365 s, full function  in 0.029 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.022819 s, full function  in 0.029 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.27e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.315e-02 m, z_w0=1.173e+01 m
# z=1.266e+01 m, z_r=2.041e+03 m
# DEBUG:poppy:  Beam radius at OAP3 =2.32e-02 m
# DEBUG:poppy: input flat wavefront and OAP3 has output beam curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curved output wavefront, with waist at 13.87423066347563 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.266e+01 m, z_r=7.261e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -1.217276467668519 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =3.42e+06 m
# DEBUG:poppy:Applying spherical lens phase =2.92e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP3
# DEBUG:poppy:------ Optic: OAP3 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 3 after distance 0.505329955078121 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.87423066347563 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.630067884374152e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=1.2172760346040903 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020335 s, full function  in 0.033 s
# DEBUG:poppy:Applying spherical phase curvature =1.22e+00 m
# DEBUG:poppy:Applying spherical lens phase =8.22e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.0844902857014155e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.7119460795259691 m
# DEBUG:poppy:Applying spherical phase curvature =-7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.021826 s, full function  in 0.034 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.32e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 3
# DEBUG:poppy:  Propagating wavefront to Lens: OAP4, with focal length 0.446951159052363 m after distance 1.158897671642761 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.87423066347563 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 2.7079796073463246e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7119460795259691 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020833 s, full function  in 0.033 s
# DEBUG:poppy:Applying spherical phase curvature =7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.0844902857014155e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.4469515921167915 m
# DEBUG:poppy:Applying spherical phase curvature =4.47e-01 m
# DEBUG:poppy:Applying spherical lens phase =2.24e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020307 s, full function  in 0.032 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.43e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.432e+01 m, z_r=7.261e-04 m
# DEBUG:poppy:  Beam radius at OAP4 =8.50e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.432e+01 m, z_r=7.261e-04 m
# DEBUG:poppy: input curved wavefront and OAP4 has output beam curvature of =-1.24e+05 m
# DEBUG:poppy:OAP4 has a curvature of =-1.24e+05 m
# DEBUG:poppy:OAP4 has a curved output wavefront, with waist at 14.932241851791904 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.500e-03 m, z_w0=1.493e+01 m
# z=1.432e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:Magnification: -277176.53597631963  from R_in = 0.4469515921167915 m, R_out = -123884.4940520332 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-4.61e+05 m
# DEBUG:poppy:Applying spherical lens phase =-2.17e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP4
# DEBUG:poppy:------ Optic: OAP4 applied ------
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Shaped Pupil Mask  after distance 0.423013568764728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.932241851791904 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.423013568764728 m
# DEBUG:poppy:  Constant Pixelscale: 1.7000385727653902e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020834 s, full function  in 0.027 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.028 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.47e+01 m ------
# DEBUG:poppy:Array shape (1001, 1001) is smaller than desired shape [2000, 2000]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 499 x 499 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Shaped Pupil Mask
# DEBUG:poppy:  Propagating wavefront to Lens: OAP5, with focal length 0.548189351937178 m after distance 0.408810648253099 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.932241851791904 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.408810648253099 m
# DEBUG:poppy:  Constant Pixelscale: 1.7000385727653902e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020832 s, full function  in 0.026 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019839 s, full function  in 0.026 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.52e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.500e-03 m, z_w0=1.493e+01 m
# z=1.515e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:  Beam radius at OAP5 =8.50e-03 m
# DEBUG:poppy: input flat wavefront and OAP5 has output beam curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curved output wavefront, with waist at 15.701193648385914 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.515e+01 m, z_r=1.092e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.548189351937178 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.38e+05 m
# DEBUG:poppy:Applying spherical lens phase =7.24e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP5
# DEBUG:poppy:------ Optic: OAP5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: ANNULAR FPM after distance 0.548189083164429 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.701193648385914 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5481871757756647 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018353 s, full function  in 0.024 s
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.026 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.026 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.57e+01 m ------
# DEBUG:poppy:------ Applying FITS FPM using FFT and MFT sequence ------
# DEBUG:poppy:Calculating FPM phasor from numexpr.
# DEBUG:poppy:MatrixFourierTransform initialized using centering type = ADJUSTABLE
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020336 s, full function  in 0.074 s
# DEBUG:poppy:Forward MatrixFourierTransform: array shape (2000, 2000), centering style ADJUSTABLE, output region size 82.10000000000001 in lambda / D units, output array size 821 pixels, offset None
# DEBUG:poppy:Inverse MatrixFourierTransform: array shape (821, 821), centering style ADJUSTABLE, output region size 82.10000000000001 in lambda / D units, output array size 2000 pixels, offset None
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.025821 s, full function  in 0.072 s
# DEBUG:poppy:------ FITs FPM Optic: ANNULAR FPM applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: OAP6, with focal length 0.548189083164429 m after distance 0.548189083164429 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.701193648385914 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.3301298784040463e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.021327 s, full function  in 0.032 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.022321 s, full function  in 0.030 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.548190990553195 m
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.032 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.62e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP6 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.625e+01 m, z_r=1.092e-03 m
# DEBUG:poppy:  Beam radius at OAP6 =8.50e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.625e+01 m, z_r=1.092e-03 m
# DEBUG:poppy: input curved wavefront and OAP6 has output beam curvature of =-7.36e+04 m
# DEBUG:poppy:OAP6 has a curvature of =-7.36e+04 m
# DEBUG:poppy:OAP6 has a curved output wavefront, with waist at 17.278057427889884 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.500e-03 m, z_w0=1.728e+01 m
# z=1.625e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:Magnification: -134244.28616212297  from R_in = 0.548190990553195 m, R_out = -73591.50820732076 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-1.58e+05 m
# DEBUG:poppy:Applying spherical lens phase =-6.35e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP6
# DEBUG:poppy:------ Optic: OAP6 applied ------
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Lyot Stop  after distance 0.687567667550736 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.278057427889884 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.687567667550736 m
# DEBUG:poppy:  Constant Pixelscale: 1.7000504031569692e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.026 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019841 s, full function  in 0.027 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.69e+01 m ------
# DEBUG:poppy:Array shape (1002, 1002) is smaller than desired shape [2000, 2000]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 499 x 499 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Lyot Stop
# DEBUG:poppy:  Propagating wavefront to Lens: OAP7, with focal length 0.708251083480054 m after distance 0.401748843470518 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.278057427889884 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.401748843470518 m
# DEBUG:poppy:  Constant Pixelscale: 1.7000504031569692e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.021824 s, full function  in 0.033 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019345 s, full function  in 0.026 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.73e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP7 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.500e-03 m, z_w0=1.728e+01 m
# z=1.734e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:  Beam radius at OAP7 =8.50e-03 m
# DEBUG:poppy: input flat wavefront and OAP7 has output beam curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curved output wavefront, with waist at 18.046947540339012 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.734e+01 m, z_r=1.823e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.708251083480054 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.07e+05 m
# DEBUG:poppy:Applying spherical lens phase =9.36e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP7
# DEBUG:poppy:------ Optic: OAP7 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fieldstop Plane (No Optic) after distance 0.708251083480054 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.046947540339012 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7082463903786511 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018849 s, full function  in 0.025 s
# DEBUG:poppy:Applying spherical phase curvature =7.08e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020337 s, full function  in 0.029 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018352 s, full function  in 0.030 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.80e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fieldstop Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP8, with focal length 0.210985967281651 m after distance 0.210985967281651 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.046947540339012 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.7184880841689884e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020831 s, full function  in 0.027 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.021329 s, full function  in 0.029 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.2109906603830538 m
# DEBUG:poppy:Applying spherical phase curvature =2.11e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.74e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.021328 s, full function  in 0.034 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.83e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP8 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.826e+01 m, z_r=1.823e-03 m
# DEBUG:poppy:  Beam radius at OAP8 =2.53e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.826e+01 m, z_r=1.823e-03 m
# DEBUG:poppy: input curved wavefront and OAP8 has output beam curvature of =-2.18e+03 m
# DEBUG:poppy:OAP8 has a curvature of =-2.18e+03 m
# DEBUG:poppy:OAP8 has a curved output wavefront, with waist at 18.531776282775454 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.532e-03 m, z_w0=1.853e+01 m
# z=1.826e+01 m, z_r=2.442e+01 m
# DEBUG:poppy:Magnification: -10319.573993647911  from R_in = 0.2109906603830538 m, R_out = -2177.3337317915607 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-9.49e+03 m
# DEBUG:poppy:Applying spherical lens phase =-1.05e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP8
# DEBUG:poppy:------ Optic: OAP8 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Filter after distance 0.36845226822553 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.531776282775454 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.36845226822553 m
# DEBUG:poppy:  Constant Pixelscale: 5.064547622400109e-06 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020832 s, full function  in 0.027 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020336 s, full function  in 0.029 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.86e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Filter
# DEBUG:poppy:  Propagating wavefront to Lens: LENS, with focal length 0.296018684431726 m after distance 0.170799548215162 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.531776282775454 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.170799548215162 m
# DEBUG:poppy:  Constant Pixelscale: 5.064547622400109e-06 m / pix
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.019840 s, full function  in 0.026 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019343 s, full function  in 0.026 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.88e+01 m ------
# DEBUG:poppy:------ Applying Lens: LENS ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.532e-03 m, z_w0=1.853e+01 m
# z=1.880e+01 m, z_r=2.442e+01 m
# DEBUG:poppy:  Beam radius at LENS =2.53e-03 m
# DEBUG:poppy: input flat wavefront and LENS has output beam curvature of =-2.96e-01 m
# DEBUG:poppy:LENS has a curvature of =-2.96e-01 m
# DEBUG:poppy:LENS has a curved output wavefront, with waist at 19.093165207859226 m
# DEBUG:poppy:Post Optic Parameters:w_0:3.070e-05 m, z_w0=1.909e+01 m
# z=1.880e+01 m, z_r=3.588e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.296018684431726 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =2.01e+03 m
# DEBUG:poppy:Applying spherical lens phase =4.96e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: LENS
# DEBUG:poppy:------ Optic: LENS applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 4 after distance 0.246017378417573 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.093165207859226 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 5.064547622400109e-06 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.2959751906964705 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020336 s, full function  in 0.029 s
# DEBUG:poppy:Applying spherical phase curvature =2.96e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.38e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.4106746597129493e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.049957812278897507 m
# DEBUG:poppy:Applying spherical phase curvature =-5.00e-02 m
# DEBUG:poppy:Applying spherical lens phase =-2.00e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020339 s, full function  in 0.031 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.90e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 4
# DEBUG:poppy:  Propagating wavefront to Optic: focus after distance 0.05000157851465 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.093165207859226 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.049957812278897507 m
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.020885 s, full function  in 0.026 s
# DEBUG:poppy:Applying spherical phase curvature =5.00e-02 m
# DEBUG:poppy:Applying spherical lens phase =2.00e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.020864 s, full function  in 0.028 s
# DEBUG:poppy:using mkl_fft FFT of (2000, 2000) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.022320 s, full function  in 0.028 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.91e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: focus
# INFO:poppy:  Calculation completed in 13.517 s
# INFO:poppy:PSF Calculation completed.
# PSF calculated in 14.46s
# FPM pixelscale:  1.3301298784040463e-05 m / pix
# PSF pixelscale:  2.4106746597129493e-05 m / pix

# %%
reload(modes)
reload(misc)
prop_psf_fpath = Path('proper-psfs/spc-wide/proper_psf_onax.fits')
modes.compare_psfs(wfs[-1], prop_psf_fpath, vmin=1e-18)
# Out:
# PROPER wavefront pixelscale:  4.82220314538878e-06 m / pix
# PROPER wavefront pixelscale in λ/D:  0.1
# Input POPPY wavefront pixelscale:  2.4106746597129493e-05 m / pix
# Interpolated POPPY wavefront pixelscale:  4.82220314538878e-06 m / pix

# %% [markdown]
# # Save the wavefronts to a specific directory if desired.

# %%
reload(misc)
misc.save_waves(wfs, use_apertures, use_opds, npix=1000, wfdir=Path('C:/Users/Kian Milani/Desktop/roman-waves/spc-wide'))
# Out:
# Saving wavefronts:
# 0 Saved pupil wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_pupil_poppy.fits
# 1 Saved primary wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_primary_poppy.fits
# 2 Saved secondary wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_secondary_poppy.fits
# 3 Saved fold1 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fold1_poppy.fits
# 4 Saved m3 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_m3_poppy.fits
# 5 Saved m4 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_m4_poppy.fits
# 6 Saved m5 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_m5_poppy.fits
# 7 Saved fold2 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fold2_poppy.fits
# 8 Saved fsm wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fsm_poppy.fits
# 9 Saved oap1 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap1_poppy.fits
# 10 Saved focm wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_focm_poppy.fits
# 11 Saved oap2 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap2_poppy.fits
# 12 Saved dm1 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_dm1_poppy.fits
# 13 Saved dm2 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_dm2_poppy.fits
# 14 Saved oap3 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap3_poppy.fits
# 15 Saved fold3 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fold3_poppy.fits
# 16 Saved oap4 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap4_poppy.fits
# 17 Saved spm wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_spm_poppy.fits
# 18 Saved oap5 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap5_poppy.fits
# 19 Saved fpm wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fpm_poppy.fits
# 20 Saved oap6 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap6_poppy.fits
# 21 Saved lyotstop wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_lyotstop_poppy.fits
# 22 Saved oap7 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap7_poppy.fits
# 23 Saved fieldstop wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fieldstop_poppy.fits
# 24 Saved oap8 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_oap8_poppy.fits
# 25 Saved filter wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_filter_poppy.fits
# 26 Saved lens wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_lens_poppy.fits
# 27 Saved fold4 wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_fold4_poppy.fits
# 28 Saved image wavefront to C:\Users\Kian Milani\Desktop\roman-waves\spc-wide\wf_image_poppy.fits
# All wavefronts saved.
